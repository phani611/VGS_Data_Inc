# %%
import xml.etree.ElementTree as ET
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
cc = pd.read_csv('C:/Users/ecn/Desktop/VGS - Data Incubator/Country codes.csv')
cc
# Out:
# AW
# AF
# AO
# AL
# AD
# 1A
# AE
# AR
# AM
# AS
# AG
# AU
# AT
# AZ
# BI
# BE
# BJ
# BF
# BD
# BG
# BH
# BS
# BA
# BY
# BZ
# BM
# BO
# BR
# BB
# BN
# BT
# BW
# CF
# CA
# B8
# CH
# CL
# CN
# CI
# CM
# CD
# CG
# CO
# KM
# CV
# CR
# S3
# CU
# CW
# KY
# CY
# CZ
# DE
# DJ
# DM
# DK
# DO
# DZ
# 4E
# V2
# Z4
# 7E
# Z7
# EC
# EG
# XC
# ER
# ES
# EE
# ET
# EU
# F1
# FI
# FJ
# FR
# FO
# FM
# GA
# GB
# GE
# GH
# GI
# GN
# GM
# GW
# GQ
# GR
# GD
# GL
# GT
# GU
# GY
# XD
# HK
# HN
# XE
# HR
# HT
# HU
# XF
# ZT
# XG
# XH
# ID
# XI
# IM
# IN
# IE
# IR
# IQ
# IS
# IL
# IT
# JM
# JO
# JP
# KZ
# KE
# KG
# KH
# KI
# KN
# KR
# KW
# XJ
# LA
# LB
# LR
# LY
# LC
# ZJ
# XL
# XM
# LI
# LK
# XN
# XO
# LS
# V3
# LT
# LU
# LV
# MO
# MF
# MA
# MC
# MD
# MG
# MV
# ZQ
# MX
# MH
# XP
# MK
# ML
# MT
# MM
# XQ
# ME
# MN
# MP
# MZ
# MR
# MU
# MW
# MY
# XU
# nan
# NC
# NE
# NG
# NI
# NL
# NO
# NP
# NR
# NZ
# OE
# OM
# S4
# PK
# PA
# PE
# PH
# PW
# PG
# PL
# V1
# PR
# KP
# PT
# PY
# PS
# S2
# V4
# PF
# QA
# RO
# RU
# ...

# %%
##'http://api.worldbank.org/countries/us/indicators/EN.ATM.GHGT.KT.CE?date=1970:2016'
url_1 = 'http://api.worldbank.org/countries/'
url_2 = 'US' ##should go in loop
url_3 = '/indicators/EN.ATM.GHGT.KT.CE?date=1970:2016'
url = url_1 + url_2 + url_3
s = requests.get(url)
tree = ET.fromstring(s.content)

# %%
s.content
# Out:
# b'\xef\xbb\xbf<?xml version="1.0" encoding="utf-8"?>\r\n<wb:data page="1" pages="1" per_page="50" total="47" xmlns:wb="http://www.worldbank.org">\r\n  <wb:data>\r\n    <wb:indicator id="EN.ATM.GHGT.KT.CE">Total greenhouse gas emissions (kt of CO2 equivalent)</wb:indicator>\r\n    <wb:country id="US">United States</wb:country>\r\n    <wb:date>2016</wb:date>\r\n    <wb:value />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="EN.ATM.GHGT.KT.CE">Total greenhouse gas emissions (kt of CO2 equivalent)</wb:indicator>\r\n    <wb:country id="US">United States</wb:country>\r\n    <wb:date>2015</wb:date>\r\n    <wb:value />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="EN.ATM.GHGT.KT.CE">Total greenhouse gas emissions (kt of CO2 equivalent)</wb:indicator>\r\n    <wb:country id="US">United States</wb:country>\r\n    <wb:date>2014</wb:date>\r\n    <wb:value />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n
# ...

# %%
tree
# Out:
# <Element '{http://www.worldbank.org}data' at 0x0000000009B40548>

# %%
for index, row in cc.iterrows():    
    url_2 = row['2-alpha code'] ##should go in loop
    print(url_2)
# Out:
# AW
# AF
# AO
# AL
# AD
# 1A
# AE
# AR
# AM
# AS
# AG
# AU
# AT
# AZ
# BI
# BE
# BJ
# BF
# BD
# BG
# BH
# BS
# BA
# BY
# BZ
# BM
# BO
# BR
# BB
# BN
# BT
# BW
# CF
# CA
# B8
# CH
# CL
# CN
# CI
# CM
# CD
# CG
# CO
# KM
# CV
# CR
# S3
# CU
# CW
# KY
# CY
# CZ
# DE
# DJ
# DM
# DK
# DO
# DZ
# 4E
# V2
# Z4
# 7E
# Z7
# EC
# EG
# XC
# ER
# ES
# EE
# ET
# EU
# F1
# FI
# FJ
# FR
# FO
# FM
# GA
# GB
# GE
# GH
# GI
# GN
# GM
# GW
# GQ
# GR
# GD
# GL
# GT
# GU
# GY
# XD
# HK
# HN
# XE
# HR
# HT
# HU
# XF
# ZT
# XG
# XH
# ID
# XI
# IM
# IN
# IE
# IR
# IQ
# IS
# IL
# IT
# JM
# JO
# JP
# KZ
# KE
# KG
# KH
# KI
# KN
# KR
# KW
# XJ
# LA
# LB
# LR
# LY
# LC
# ZJ
# XL
# XM
# LI
# LK
# XN
# XO
# LS
# V3
# LT
# LU
# LV
# MO
# MF
# MA
# MC
# MD
# MG
# MV
# ZQ
# MX
# MH
# XP
# MK
# ML
# MT
# MM
# XQ
# ME
# MN
# MP
# MZ
# MR
# MU
# MW
# MY
# XU
# nan
# NC
# NE
# NG
# NI
# NL
# NO
# NP
# NR
# NZ
# OE
# OM
# S4
# PK
# PA
# PE
# PH
# PW
# PG
# PL
# V1
# PR
# KP
# PT
# PY
# PS
# S2
# V4
# PF
# QA
# RO
# RU
# ...

# %%
url_1 = 'http://api.worldbank.org/countries/'
url_3 = '/indicators/EN.ATM.GHGT.KT.CE?date=1970:2016'
i = 0
year = []
AW_co2 = []
AF_co2 = []
AO_co2 = []
US_co2 = []
CN_co2 = []

for index, row in cc.iterrows():    
    i = i + 1
    url_2 = row['2-alpha code'] ##should go in loop
    if i == 4 :
        url_2 = 'US'
    elif i == 5 :
        url_2 = 'CN'
        
    url = url_1 + url_2 + url_3
    print(url_2)
    s = requests.get(url)
    tree = ET.fromstring(s.content)


    for child1 in tree:
        for child2 in child1:
            if child2.tag == '{http://www.worldbank.org}date' and i == 5:
                year.append(child2.text)
            if child2.tag == '{http://www.worldbank.org}value' and i == 1:
                AW_co2.append(child2.text)
            elif child2.tag == '{http://www.worldbank.org}value' and i == 2:
                AF_co2.append(child2.text)
            elif child2.tag == '{http://www.worldbank.org}value' and i == 3:
                AO_co2.append(child2.text)
            elif child2.tag == '{http://www.worldbank.org}value' and i == 4:
                US_co2.append(child2.text)
            elif child2.tag == '{http://www.worldbank.org}value' and i == 5:
                CN_co2.append(child2.text)
    if i == 5:
        df = pd.DataFrame(
                    {'Aruban florin CO2': AW_co2,
                     'Afghan afghani' : AF_co2,
                     'Angolan' : AO_co2,
                     'US' : US_co2,
                     'CN' : CN_co2,
                     'Year': year
                    })   
        break          
 
    
    ##final_df.append(df, ignore_index = True)
# Out:
# AW
# AF
# AO
# US
# CN

# %%
df.shape
df.memory_usage(index=False)
# Out:
# Afghan afghani       376
# Angolan              376
# Aruban florin CO2    376
# CN                   376
# US                   376
# Year                 376
# dtype: int64

# %%
df
# Out:
#       Afghan afghani           Angolan Aruban florin CO2              CN  \
# 0               None              None              None            None
# 1               None              None              None            None
# 2               None              None              None            None
# 3               None              None              None            None
# 4               None  41657.1648460299              None   12454710.6051
# 5   17981.3072867677  40878.6519582578              None  12064260.00255
# 6   17791.3299018728  40029.3921005695              None      11183810.6
# 7   15554.4294997907  38309.4651264052              None      10617264.9
# 8         15288.7756         37396.294              None      10022024.8
# 9          15272.633         36690.534              None       9124046.5
# 10        14849.1594         36375.822              None       8573395.4
# 11        14770.2643        35855.7384              None       7803535.6
# ...

# %%
##df_1 = pd.DataFrame(df['Afghan afghani','Angolan','Aruban florin CO2','CN', 'US'], index=df['Year'], columns=['Afghan afghani','Angolan','Aruban florin CO2','CN', 'US'])
df.ix[:,'b':]
df_1 = pd.DataFrame(df.ix[:,:'US'].values.astype(float), index=df['Year'], columns=['Afghan afghani','Angolan','Aruban florin CO2','CN', 'US'])

# %%
df_1
# Out:
#       Afghan afghani       Angolan  Aruban florin CO2            CN  \
# Year
# 2016             NaN           NaN                NaN           NaN
# 2015             NaN           NaN                NaN           NaN
# 2014             NaN           NaN                NaN           NaN
# 2013             NaN           NaN                NaN           NaN
# 2012             NaN  41657.164846                NaN  1.245471e+07
# 2011    17981.307287  40878.651958                NaN  1.206426e+07
# 2010    17791.329902  40029.392101                NaN  1.118381e+07
# 2009    15554.429500  38309.465126                NaN  1.061726e+07
# 2008    15288.775600  37396.294000                NaN  1.002202e+07
# 2007    15272.633000  36690.534000                NaN  9.124046e+06
# 2006    14849.159400  36375.822000                NaN  8.573395e+06
# 2005    14770.264300  35855.738400                NaN  7.803536e+06
# 2004    14654.374000  36860.233400                NaN  7.116642e+06
# ...

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)
plt.figure(figsize=(100, 100), dpi=800, facecolor='w', edgecolor='k'); df_1.plot();
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Plot the data
ts = pd.Series(final_df['CO2'].values.astype(float), index=pd.date_range('1970', freq = 'A', periods=47))
##ts=ts.astype(float)
ts

#plt.plot(final_df['Year'], final_df['CO2'], label='USA')

# Add a legend
#plt.legend()

# Show the plot
#plt.show()
# Out:
# 1970-12-31             NaN
# 1971-12-31             NaN
# 1972-12-31             NaN
# 1973-12-31             NaN
# 1974-12-31    6.343841e+06
# 1975-12-31    6.571654e+06
# 1976-12-31    6.713349e+06
# 1977-12-31    6.604069e+06
# 1978-12-31    6.648991e+06
# 1979-12-31    7.128952e+06
# 1980-12-31    6.994087e+06
# 1981-12-31    7.182808e+06
# 1982-12-31    7.244272e+06
# 1983-12-31    6.991255e+06
# 1984-12-31    6.981787e+06
# 1985-12-31    6.821236e+06
# 1986-12-31    6.969124e+06
# 1987-12-31    6.808138e+06
# 1988-12-31    6.749016e+06
# 1989-12-31    6.724414e+06
# 1990-12-31    6.577713e+06
# 1991-12-31    6.365297e+06
# 1992-12-31    6.374979e+06
# 1993-12-31    6.282704e+06
# 1994-12-31    6.137498e+06
# 1995-12-31    6.073644e+06
# 1996-12-31    6.136094e+06
# 1997-12-31    6.221392e+06
# 1998-12-31    6.185748e+06
# 1999-12-31    5.743633e+06
# 2000-12-31    5.731026e+06
# 2001-12-31    5.776898e+06
# 2002-12-31    5.761217e+06
# 2003-12-31    5.524778e+06
# ...

# %%
ts.plot()
plt.show()
# Out:
# C:\Users\ecn\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
final_df['CO2']
# Out:
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4     6343840.50774614
# 5     6571653.97696764
# 6     6713348.96911148
# 7      6604068.9516624
# 8            6648991.2
# 9            7128951.7
# 10           6994086.9
# 11           7182808.4
# 12           7244271.5
# 13           6991255.2
# 14           6981786.8
# 15           6821235.6
# 16           6969123.8
# 17           6808137.8
# 18           6749016.1
# 19           6724414.4
# 20           6577713.1
# 21           6365296.6
# 22           6374979.2
# 23           6282704.3
# 24           6137498.4
# 25           6073643.8
# 26           6136093.5
# 27           6221391.6
# 28             6185748
# 29           5743632.7
# 30           5731026.3
# 31           5776897.6
# 32           5761217.3
# 33           5524777.8
# 34             5534118
# 35           5830249.4
# 36           5896082.8
# 37           6135462.9
# 38           6054464.7
# 39           6048233.1
# ...

# %%
while k < 100:
    
    k = k + 1
    j = 0
    
    while j < 4:
        j = j + 1
        if j == 1:
            
            country = [] ##create empty list
            year = []
            gdp = []

            i = 0
            for child1 in tree:
                for child2 in child1:
                    for child3 in child2:
                        for child4 in child3:                
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}precipitationAmount' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                ##print(child3.tag, child4.tag, child4.text)
                                i = i + 1
                                if i % 2 == 0:
                                    pamt_snow.append(child4.text)
                                else:
                                    pamt_rain.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}avgWindSpeed' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                avg_wind.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}maxWindSpeed' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                max_wind.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}avgTemperature' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                avg_temp.append(child4.text)


            for child1 in tree:
                for child2 in child1:
                    for child3 in child2:
                        if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}sunrise':
                            w_date.append(child3.text[:10])

            final_df = pd.DataFrame(
                {'Snow': pamt_snow,
                 'Rain': pamt_rain,
                 'Avg_Wind': avg_wind,
                 'Max_Wind': max_wind,
                 'Avg_temp': avg_temp,
                 'Date'    : w_date
                })

            ##final_df.to_csv('Weather data',sep=',' )
            final_df.to_csv(url_8 + url_2 + url_5,sep=',' )
            print(url_8 + url_2 + url_5)
            
        elif j == 2:
            
            url_2 = '2015-08-01'
            url_5 = '2015-09-01'            
            
            url = url_1 + url_2 + url_3 + url_4 + url_5 + url_6 + url_7 + url_8 + url_9 + url_10
            t = requests.get(url, auth=HTTPBasicAuth('chittavajhula2497019', 'zRRATRG3U0Unv124'))
            
            tree = ET.fromstring(t.content)
            
            pamt_snow = [] ##create empty list
            pamt_rain = []
            avg_wind = []
            max_wind = []
            avg_temp = []
            w_date   = []

            i = 0
            for child1 in tree:
                for child2 in child1:
                    for child3 in child2:
                        for child4 in child3:                
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}precipitationAmount' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                ##print(child3.tag, child4.tag, child4.text)
                                i = i + 1
                                if i % 2 == 0:
                                    pamt_snow.append(child4.text)
                                else:
                                    pamt_rain.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}avgWindSpeed' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                avg_wind.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}maxWindSpeed' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                max_wind.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}avgTemperature' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                avg_temp.append(child4.text)


            for child1 in tree:
                for child2 in child1:
                    for child3 in child2:
                        if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}sunrise':
                            w_date.append(child3.text[:10])

            final_df = pd.DataFrame(
                {'Snow': pamt_snow,
                 'Rain': pamt_rain,
                 'Avg_Wind': avg_wind,
                 'Max_Wind': max_wind,
                 'Avg_temp': avg_temp,
                 'Date'    : w_date
                })

            ##final_df.to_csv('Weather data',sep=',' )
            final_df.to_csv(url_8 + url_2 + url_5,sep=',' )
            print(url_8 + url_2 + url_5)
            
        elif j == 3:
            
            url_2 = '2015-09-01'
            url_5 = '2015-10-01'

            url = url_1 + url_2 + url_3 + url_4 + url_5 + url_6 + url_7 + url_8 + url_9 + url_10
            t = requests.get(url, auth=HTTPBasicAuth('chittavajhula2497019', 'zRRATRG3U0Unv124'))
            
            tree = ET.fromstring(t.content)
            
            pamt_snow = [] ##create empty list
            pamt_rain = []
            avg_wind = []
            max_wind = []
            avg_temp = []
            w_date   = []

            i = 0
            for child1 in tree:
                for child2 in child1:
                    for child3 in child2:
                        for child4 in child3:                
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}precipitationAmount' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                ##print(child3.tag, child4.tag, child4.text)
                                i = i + 1
                                if i % 2 == 0:
                                    pamt_snow.append(child4.text)
                                else:
                                    pamt_rain.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}avgWindSpeed' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                avg_wind.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}maxWindSpeed' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                max_wind.append(child4.text)
                            if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}avgTemperature' and child4.tag == '{http://weather.dtn.com/rest-3.4/doc/}value':
                                avg_temp.append(child4.text)


            for child1 in tree:
                for child2 in child1:
                    for child3 in child2:
                        if child3.tag == '{http://weather.dtn.com/rest-3.4/doc/}sunrise':
                            w_date.append(child3.text[:10])

            final_df = pd.DataFrame(
                {'Snow': pamt_snow,
                 'Rain': pamt_rain,
                 'Avg_Wind': avg_wind,
                 'Max_Wind': max_wind,
                 'Avg_temp': avg_temp,
                 'Date'    : w_date
                })

            ##final_df.to_csv('Weather data',sep=',' )
            final_df.to_csv(url_8 + url_2 + url_5,sep=',' )
            print(url_8 + url_2 + url_5)
